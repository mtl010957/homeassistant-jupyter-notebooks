# %%
from detective.core import db_from_hass_config

# %%
db2 = db_from_hass_config()
db2.fetch_all_data()
# Out:
# Successfully connected to database mysql://homeassistant:***@raspberrypi/HA?charset=utf8
# There are 18 entities with data
# Querying the database, this could take a while
# master_df created successfully.

# %%
assert 'binary_sensor' and 'sensor' in db2.domains

# %%
from detective.core import NumericalSensors
NumericalSensors(db2.master_df.query('entity == ["sensor.temperature_probe_1_f","sensor.temperature_probe_2_f","sensor.temperature_probe_3_f","sensor.temperature_probe_4_f"] & last_changed > "2019-01-22 18:50:00"')).plot(['sensor.temperature_probe_1_f','sensor.temperature_probe_2_f','sensor.temperature_probe_3_f','sensor.temperature_probe_4_f'])
